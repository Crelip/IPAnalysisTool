# %%
from ip_analysis_tool.ping.ping_topology_latency_correlation import ping_topology_latency_correlation
from ip_analysis_tool.enums import TimeInterval
data = ping_topology_latency_correlation(TimeInterval.WEEK, True)
# Out:
# WEEK 2009-06-15: Topology Latency: 63.858466136812005ms, DB Latency: 58.09345533597012ms, Ratio: 0.9097220595857912
# WEEK 2009-06-22: Topology Latency: 86.39475775658812ms, DB Latency: 83.77360705495056ms, Ratio: 0.9696607668138558
# WEEK 2009-06-29: Topology Latency: 87.55160058955147ms, DB Latency: 82.44793135175277ms, Ratio: 0.9417067283358407
# WEEK 2009-07-06: Topology Latency: 91.59786648088975ms, DB Latency: 83.71033394878762ms, Ratio: 0.9138895605854781
# WEEK 2009-07-13: Topology Latency: 94.57041465531698ms, DB Latency: 82.90601508031078ms, Ratio: 0.8766591050962427
# WEEK 2009-07-20: Topology Latency: 91.32182835453453ms, DB Latency: 82.60750360297297ms, Ratio: 0.9045756648921839
# WEEK 2009-07-27: Topology Latency: 92.05547529078724ms, DB Latency: 83.54834957683016ms, Ratio: 0.9075869665863486
# WEEK 2009-08-03: Topology Latency: 98.22416887163695ms, DB Latency: 86.43155830444181ms, Ratio: 0.8799418645872569
# ...

# %%
from ip_analysis_tool.visualize.chart import visualize_chart_dual
visualize_chart_dual(data = data, y_characteristic="topology_latency",
                     y_2_characteristic="ping_latency",
                     title="Porovnanie oneskorení z relácií ping a topology",
                     y_label="oneskorenie z topology [ms]",
                     y_2_label="oneskorenie z ping [ms]",
                     )
